# %% [markdown]
# <a href="https://colab.research.google.com/github/eliotte0106/Data_Analyze-and-Image_Process/blob/main/OpenCV_Filtering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-93027f1c-271c-4792-8c0f-58b86860ddf6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-93027f1c-271c-4792-8c0f-58b86860ddf6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving stairs.jpg to stairs.jpg

# %% [markdown]
# making kernel without using blur

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

image = cv2.imread('stairs.jpg')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

size = 4
kernel = np.ones((size, size), np.float32) / (size ** 2)
print(kernel)

dst = cv2.filter2D(image, -1, kernel)
plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# [[0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]]

# %% [markdown]
# basic blurring

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('stairs.jpg')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

dst = cv2.blur(image, (4, 4))
plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# gaussian blurring

# %%
import cv2

image = cv2.imread('stairs.jpg')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# kernel_size: odd numbers
dst = cv2.GaussianBlur(image, (5, 5), 0)
plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
plt.show()
