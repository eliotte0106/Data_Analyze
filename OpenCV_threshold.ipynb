# %% [markdown]
# <a href="https://colab.research.google.com/github/eliotte0106/Data_Analyze/blob/main/OpenCV_threshold.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# cv2.threshold(image,thresh,max_value,type)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-93b8988e-fb12-4186-a0ea-f77364421524" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-93b8988e-fb12-4186-a0ea-f77364421524">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving busan.jpg to busan.jpg

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('busan.jpg',cv2.IMREAD_GRAYSCALE)

images = []
ret, thres1 = cv2.threshold(image,127,255,cv2.THRESH_BINARY)
ret, thres2 = cv2.threshold(image,127,255,cv2.THRESH_BINARY_INV)
ret, thres3 = cv2.threshold(image,127,255,cv2.THRESH_TRUNC)
ret, thres4 = cv2.threshold(image,127,255,cv2.THRESH_TOZERO)
ret, thres5 = cv2.threshold(image,127,255,cv2.THRESH_TOZERO_INV)
images.append(thres1)
images.append(thres2)
images.append(thres3)
images.append(thres4)
images.append(thres5)
for i in images:
  plt.imshow(cv2.cvtColor(i,cv2.COLOR_GRAY2RGB))
  plt.show()

# %% [markdown]
# cv2.adaptiveThreshold(image,max_value,adaptive_method,type,block_size,C)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-35233860-d64b-41ab-be4d-d5e8fbe0ddc6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-35233860-d64b-41ab-be4d-d5e8fbe0ddc6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving graph.png to graph.png

# %%
import cv2
image = cv2.imread('graph.png',cv2.IMREAD_GRAYSCALE)
ret, thres1 = cv2.threshold(image,127,255,cv2.THRESH_BINARY)
thres2 = cv2.adaptiveThreshold(image,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,21,3)

plt.imshow(cv2.cvtColor(image,cv2.COLOR_GRAY2RGB))
plt.show()

plt.imshow(cv2.cvtColor(thres1,cv2.COLOR_GRAY2RGB))
plt.show()

plt.imshow(cv2.cvtColor(thres2,cv2.COLOR_GRAY2RGB))
plt.show()
